# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# File to Load (Remember to Change These)
police_killings = "Data/police_killings.csv"

# Read Purchasing File and store into Pandas data frame
police_kills_data = pd.read_csv(police_killings)
police_kills_data
# Out:
#                 Victim's name Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez           28            Male         White
# 1     Name withheld by police          NaN            Male  Unknown race
# 2                Terry Hudson           57            Male         Black
# 3              Malik Williams           23            Male         Black
# 4           Frederick Perkins           37            Male         Black
# ...                       ...          ...             ...           ...
# 7658              Mark Chavez           49            Male      Hispanic
# 7659               Tyree Bell           31            Male         Black
# 7660      Christopher Tavares           21            Male      Hispanic
# 7661        Andrew L. Closson           21            Male         White
# 7662            Andrew Layton           26            Male         White
#
#                                  URL of image of victim  \
# 0     https://fatalencounters.org/wp-content/uploads...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7658  http://www.tricitytribuneusa.com/wp-content/up...
# 7659  http://content.omaha.com/media/maps/ps/2013/ja...
# 7660  http://www.krdo.com/image/view/-/17980228/medR...
# 7661  http://www.superiortelegram.com/sites/default/...
# 7662  http://bloximages.chicago2.vip.townnews.com/ma...
#
#      Date of Incident (month/day/year)             Street Address of Incident  \
# 0                           12/31/2019                             Broad St.
# 1                           12/31/2019                         7239-7411 I-40
# 2                           12/31/2019                         3600 N 24th St
# 3                           12/31/2019                30800 14th Avenue South
# 4                           12/31/2019                    17057 N Outer 40 Rd
# ...                                ...                                    ...
# 7658                          1/1/2013                    912 Loma Linda Ave.
# 7659                          1/1/2013                       3727 N. 42nd St.
# 7660                          1/1/2013  Highway 50 and North Elizabeth Street
# 7661                          1/1/2013                        U.S. Highway 53
# 7662                          1/1/2013                 410 S Riverfront Drive
#
#               City State  Zipcode  ... Symptoms of mental illness?  \
# 0            Globe    AZ  85501.0  ...                          No
# 1          Memphis    AR  38103.0  ...                          No
# 2            Omaha    NE  68110.0  ...                          No
# 3      Federal Way    WA  98003.0  ...                          No
# 4     Chesterfield    MO  63005.0  ...                          No
# ...            ...   ...      ...  ...                         ...
# 7658    Farmington    NM  87401.0  ...                          No
# 7659         Omaha    NE  68111.0  ...                         Yes
# 7660        Pueblo    CO  81008.0  ...                          No
# 7661        Gordon    WI  54838.0  ...         Drug or alcohol use
# 7662       Mankato    MN  56001.0  ...                          No
#
#               Unarmed Alleged Weapon (Source: WaPo)  \
# 0     Allegedly Armed                         knife
# 1             Unclear                       unclear
# 2     Allegedly Armed                           gun
# 3     Allegedly Armed                           gun
# 4             Vehicle                       vehicle
# ...               ...                           ...
# 7658  Allegedly Armed                  blunt weapon
# 7659  Allegedly Armed                           gun
# 7660  Allegedly Armed                           gun
# 7661  Allegedly Armed                           gun
# 7662          Unarmed                       unarmed
#
#      Alleged Threat Level (Source: WaPo) Fleeing (Source: WaPo)  \
# 0                                  other            not fleeing
# 1                                  other                    NaN
# 2                                 attack            not fleeing
# 3                                 attack            not fleeing
# 4                                 attack                    car
# ...                                  ...                    ...
# 7658                                 NaN                    NaN
# 7659                                 NaN                    NaN
# 7660                                 NaN                    NaN
# 7661                                 NaN                    NaN
# 7662                                 NaN                    NaN
#
#      Body Camera (Source: WaPo) WaPo ID (If included in WaPo database)  \
# 0                            no                                 5332.0
# 1                           NaN                                    NaN
# 2                            no                                 5359.0
# 3                            no                                 5358.0
# 4                            no                                 5333.0
# ...                         ...                                    ...
# 7658                        NaN                                    NaN
# 7659                        NaN                                    NaN
# 7660                        NaN                                    NaN
# 7661                        NaN                                    NaN
# 7662                        NaN                                    NaN
#
#      Off-Duty Killing?  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 7658               NaN
# 7659               NaN
# 7660               NaN
# 7661               NaN
# 7662               NaN
#
#      Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )  \
# 0                                                 Rural
# 1                                                 Urban
# 2                                                 Urban
# 3                                              Suburban
# 4                                              Suburban
# ...                                                 ...
# 7658                                              Urban
# 7659                                              Urban
# 7660                                           Suburban
# 7661                                              Rural
# 7662                                           Suburban
#
#         ID
# 0     7664
# 1     7665
# 2     7661
# 3     7662
# 4     7667
# ...    ...
# 7658     1
# 7659     2
# 7660     4
# 7661     5
# 7662     6
#
# [7663 rows x 27 columns]

# %%
## Cleaning data

# Rename column
police_kills_data = police_kills_data.rename(columns={"Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )": "Geography"})

police_kills_data = police_kills_data.rename(columns={"Alleged Threat Level (Source: WaPo)": "Victim Threat level"})

# Fill Nan with 0
police_kills_data["Victim's age"] = police_kills_data["Victim's age"].fillna(0)
police_kills_data["Victim's gender"] = police_kills_data["Victim's gender"].fillna(0)

#print(police_kills_data["Victim's age"].fillna(0))
print(police_kills_data.columns)

# Replace unknown with 0 in Victim's age column
police_kills_data["Victim's age"] = police_kills_data["Victim's age"].replace('Unknown', 0)

#Replace #N/A with Unknown city in Geography Column
police_kills_data["Geography"] = police_kills_data["Geography"].replace('#N/A', 'Unknown city')

# Replace 40s to 45
police_kills_data["Victim's age"] = police_kills_data["Victim's age"].replace('40s', 45)

# Convert string into int
police_kills_data["Victim's age"] = pd.to_numeric(police_kills_data["Victim's age"], errors="coerce")

police_kills_data
# Out:
# Index(['Victim's name', 'Victim's age', 'Victim's gender', 'Victim's race',
#        'URL of image of victim', 'Date of Incident (month/day/year)',
#        'Street Address of Incident', 'City', 'State', 'Zipcode', 'County',
#        'Agency responsible for death', 'Cause of death',
#        'A brief description of the circumstances surrounding the death',
#        'Official disposition of death (justified or other)',
#        'Criminal Charges?',
#        'Link to news article or photo of official document',
#        'Symptoms of mental illness?', 'Unarmed',
#        'Alleged Weapon (Source: WaPo)', 'Victim Threat level',
#        'Fleeing (Source: WaPo)', 'Body Camera (Source: WaPo)',
#        'WaPo ID (If included in WaPo database)', 'Off-Duty Killing?',
#        'Geography', 'ID'],
#       dtype='object')
#                 Victim's name  Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez            28            Male         White
# 1     Name withheld by police             0            Male  Unknown race
# 2                Terry Hudson            57            Male         Black
# 3              Malik Williams            23            Male         Black
# 4           Frederick Perkins            37            Male         Black
# ...                       ...           ...             ...           ...
# 7658              Mark Chavez            49            Male      Hispanic
# 7659               Tyree Bell            31            Male         Black
# 7660      Christopher Tavares            21            Male      Hispanic
# 7661        Andrew L. Closson            21            Male         White
# 7662            Andrew Layton            26            Male         White
#
#                                  URL of image of victim  \
# 0     https://fatalencounters.org/wp-content/uploads...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7658  http://www.tricitytribuneusa.com/wp-content/up...
# 7659  http://content.omaha.com/media/maps/ps/2013/ja...
# 7660  http://www.krdo.com/image/view/-/17980228/medR...
# 7661  http://www.superiortelegram.com/sites/default/...
# 7662  http://bloximages.chicago2.vip.townnews.com/ma...
#
#      Date of Incident (month/day/year)             Street Address of Incident  \
# 0                           12/31/2019                             Broad St.
# 1                           12/31/2019                         7239-7411 I-40
# 2                           12/31/2019                         3600 N 24th St
# 3                           12/31/2019                30800 14th Avenue South
# 4                           12/31/2019                    17057 N Outer 40 Rd
# ...                                ...                                    ...
# 7658                          1/1/2013                    912 Loma Linda Ave.
# 7659                          1/1/2013                       3727 N. 42nd St.
# 7660                          1/1/2013  Highway 50 and North Elizabeth Street
# 7661                          1/1/2013                        U.S. Highway 53
# 7662                          1/1/2013                 410 S Riverfront Drive
#
#               City State  Zipcode  ... Symptoms of mental illness?  \
# 0            Globe    AZ  85501.0  ...                          No
# 1          Memphis    AR  38103.0  ...                          No
# 2            Omaha    NE  68110.0  ...                          No
# 3      Federal Way    WA  98003.0  ...                          No
# 4     Chesterfield    MO  63005.0  ...                          No
# ...            ...   ...      ...  ...                         ...
# 7658    Farmington    NM  87401.0  ...                          No
# 7659         Omaha    NE  68111.0  ...                         Yes
# 7660        Pueblo    CO  81008.0  ...                          No
# 7661        Gordon    WI  54838.0  ...         Drug or alcohol use
# 7662       Mankato    MN  56001.0  ...                          No
#
#               Unarmed Alleged Weapon (Source: WaPo) Victim Threat level  \
# 0     Allegedly Armed                         knife               other
# 1             Unclear                       unclear               other
# 2     Allegedly Armed                           gun              attack
# 3     Allegedly Armed                           gun              attack
# 4             Vehicle                       vehicle              attack
# ...               ...                           ...                 ...
# 7658  Allegedly Armed                  blunt weapon                 NaN
# 7659  Allegedly Armed                           gun                 NaN
# 7660  Allegedly Armed                           gun                 NaN
# 7661  Allegedly Armed                           gun                 NaN
# 7662          Unarmed                       unarmed                 NaN
#
#      Fleeing (Source: WaPo) Body Camera (Source: WaPo)  \
# 0               not fleeing                         no
# 1                       NaN                        NaN
# 2               not fleeing                         no
# 3               not fleeing                         no
# 4                       car                         no
# ...                     ...                        ...
# 7658                    NaN                        NaN
# 7659                    NaN                        NaN
# 7660                    NaN                        NaN
# 7661                    NaN                        NaN
# 7662                    NaN                        NaN
#
#      WaPo ID (If included in WaPo database) Off-Duty Killing? Geography    ID
# 0                                    5332.0               NaN     Rural  7664
# 1                                       NaN               NaN     Urban  7665
# 2                                    5359.0               NaN     Urban  7661
# 3                                    5358.0               NaN  Suburban  7662
# 4                                    5333.0               NaN  Suburban  7667
# ...                                     ...               ...       ...   ...
# 7658                                    NaN               NaN     Urban     1
# 7659                                    NaN               NaN     Urban     2
# 7660                                    NaN               NaN  Suburban     4
# 7661                                    NaN               NaN     Rural     5
# 7662                                    NaN               NaN  Suburban     6
#
# [7663 rows x 27 columns]

# %%
## Calculate the total count and percentage of victims in each group

# Create the bins for ages which is reference from police killings data
bins = [0, 1, 17, 24, 39, 64, 999]

# Create the names for the bins
group_names = ["unknown", "<18", "18-25", "26-39", "40-65", "65+"]

# Place the data series into a new column inside of the DataFrame
age_df = police_kills_data
age_df["Age Demographics"] = pd.cut(age_df["Victim's age"], bins, labels=group_names)

# Create a GroupBy object based upon "View Group"
age_group = age_df.groupby("Age Demographics")

#Calculate total count
unique_age_count = age_group["Victim's name"].nunique()

#Calculate total victim count
total_victims = len(age_df["Victim's name"].unique())

#Calculate percentage for each age group
percentage_victims = round((unique_age_count/total_victims)*100,2)

#Create DataFrame 
age_kills_summary = pd.DataFrame({"Total count":unique_age_count,"Percentage of victims":percentage_victims})
age_kills_summary

# Save dataframe 
age_kills_summary.to_csv("age_table")

# %%
## Gender vs age demographics
# Create a GroupBy object based upon "View Group"
age_group = age_df.groupby("Age Demographics")
age_by_gender = age_group["Victim's gender"].value_counts()
age_by_gender

# Save dataframe 
#age_by_gender.to_csv("gender_table")
# Out:
# Age Demographics  Victim's gender
# unknown           Male                  3
# <18               Male                141
#                   Female               10
# 18-25             Male               1143
#                   Female               55
#                   Transgender           3
# 26-39             Male               3201
#                   Female              164
#                   Transgender           4
#                   Unknown               2
# 40-65             Male               2348
#                   Female              143
# 65+               Male                231
#                   Female               10
# Name: Victim's gender, dtype: int64

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
male = [3, 141, 1143, 3201, 2348, 231]
female = [0, 10, 55, 164, 143, 10]
transgender = [0, 0, 3, 0, 0, 0]
unknown = [0, 0, 0, 2, 0, 0]
 
# Set position of bar on X axis
r1 = np.arange(len(male))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
 
# Make the plot
plt.bar(r1, male, color='red', width=barWidth, edgecolor='white', label='Male')
plt.bar(r2, female, color='blue', width=barWidth, edgecolor='white', label='Female')
plt.bar(r3, transgender, color='orange', width=barWidth, edgecolor='white', label='Transgender')
plt.bar(r4, unknown, color='purple', width=barWidth, edgecolor='white', label='Unknown')

# Add xticks on the middle of the group bars
plt.xlabel('Age Demographics', fontweight='bold')
plt.ylabel('Gender Counts', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(male))], ['Unknown', '<18', '18-25', '26-39', '40-65', '65+'])
plt.title('Gender portion in Age Demographics')

# Create legend & Show graphic
plt.legend()
# Save figure
plt.savefig('gender_age')

plt.show()

# %%
## Calculate gender in each age group

## Male: Start with filtering male from original age_df

# Replace blank with unknown in "Victim's gender" column
age_df["Victim's gender"] = age_df["Victim's gender"].replace(' ', 'Unknown')


# Filter male in victim gender
age_male = age_df.loc[age_df["Victim's gender"] == "Male", :]

# Rename Victim's gender to male victim
age_male = age_male.rename(columns={"Victim's gender": 'Male victim'})

# %%
# Create the bins for ages which is reference from police killings data
bins = [0, 1, 17, 24, 39, 64, 999]

# Create the names for the bins
group_names = ["unknown", "<18", "18-25", "26-39", "40-65", "65+"]

# Place the data series into a new column inside of the DataFrame
male_df = age_male
male_df["Age Demographics"] = pd.cut(male_df["Victim's age"], bins, labels=group_names)

# Create a GroupBy object based upon "View Group"
male_group = male_df.groupby("Age Demographics")

# Count male victims in each age group
male_victims_counts = male_group.count()

# Select only male victim column
male_victims_counts = male_victims_counts["Male victim"]

# Calculate percentage for female victims
male_victims_percentage = round((male_victims_counts/total_victims)*100,2)

#Create summary table
male_victim_summary = pd.DataFrame({"Male victim count":male_victims_counts,"Percentage of male victims":male_victims_percentage})

male_victim_summary

# Save dataframe 
#male_victim_summary.to_csv("male_table")
# Out:
#                   Male victim count  Percentage of male victims
# Age Demographics
# unknown                           3                        0.04
# <18                             141                        1.90
# 18-25                          1143                       15.42
# 26-39                          3201                       43.19
# 40-65                          2348                       31.68
# 65+                             231                        3.12

# %%
## Calculate gender in each age group

## Female: Start with filtering female from original age_df

# Replace blank with unknown in "Victim's gender" column
#age_df["Victim's gender"] = age_df["Victim's gender"].replace(' ', 'Unknown')

# Filter male in victim gender
age_female = age_df.loc[age_df["Victim's gender"] == "Female", :]

# Rename Victim's gender to male victim
age_female = age_female.rename(columns={"Victim's gender": 'Female victim'})

# %%
# Create the bins for ages which is reference from police killings data
bins = [0, 1, 17, 24, 39, 64, 999]

# Create the names for the bins
group_names = ["unknown", "<18", "18-25", "26-39", "40-65", "65+"]

# Place the data series into a new column inside of the DataFrame
female_df = age_female
female_df["Age Demographics"] = pd.cut(female_df["Victim's age"], bins, labels=group_names)

# Create a GroupBy object based upon "View Group"
female_group = female_df.groupby("Age Demographics")

# Count female victims in each age group
female_victims_counts = female_group.count()

# Select only female victim column
female_victims_counts = female_victims_counts["Female victim"]
female_victims_percentage = round((female_victims_counts/total_victims)*100,2)

# Create new data frame
female_victim_summary = pd.DataFrame({"Female victim count":female_victims_counts,"Percentage of female victims":female_victims_percentage})

female_victim_summary

# Save dataframe 
#female_victim_summary.to_csv("female_table")
# Out:
#                   Female victim count  Percentage of female victims
# Age Demographics
# unknown                             0                          0.00
# <18                                10                          0.13
# 18-25                              55                          0.74
# 26-39                             164                          2.21
# 40-65                             143                          1.93
# 65+                                10                          0.13

# %%
## Threat level vs age demographics
# Create a GroupBy object based upon "View Group"
age_group = age_df.groupby("Age Demographics")
age_threat_level = age_group["Victim Threat level"].value_counts()
age_threat_level

# Save dataframe 
age_threat_level.to_csv("threat_level_table")

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
other = [1, 39, 233, 737, 497, 33]
attack = [0, 62, 494, 1493, 1140, 122]
undetermine = [0, 4, 53, 129, 82, 7]
 
# Set position of bar on X axis
r1 = np.arange(len(other))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Make the plot
plt.bar(r1, other, color='grey', width=barWidth, edgecolor='white', label='Other')
plt.bar(r2, attack, color='pink', width=barWidth, edgecolor='white', label='Attack')
plt.bar(r3, undetermine, color='orange', width=barWidth, edgecolor='white', label='Undetermine')
 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.ylabel('Threat Level Counts', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(other))], ['Unknown', '<18', '18-25', '26-39', '40-65', '65+'])
plt.title('Victim Threat level in Age Demographics')

# Create legend & Show graphic
plt.legend()

# Save figure
plt.savefig('threat_levlel_age')

plt.show()

# %%
## Calculate male with attck threat level in each age group

## Male: Start with filtering male from original age_df

# Replace blank with unknown in "Victim's gender" column
#age_df["Victim's gender"] = age_df["Victim's gender"].replace(' ', 'Unknown')


# Filter male in victim gender
male_attack = age_male.loc[age_male["Victim Threat level"] == "attack", :]

# Rename Victim's gender to male victim
male_attack = age_male.rename(columns={"Victim Threat level": 'Male Threat level'})

male_attack
# Out:
#                 Victim's name  Victim's age Male victim Victim's race  \
# 0              Eric M. Tellez            28        Male         White
# 1     Name withheld by police             0        Male  Unknown race
# 2                Terry Hudson            57        Male         Black
# 3              Malik Williams            23        Male         Black
# 4           Frederick Perkins            37        Male         Black
# ...                       ...           ...         ...           ...
# 7658              Mark Chavez            49        Male      Hispanic
# 7659               Tyree Bell            31        Male         Black
# 7660      Christopher Tavares            21        Male      Hispanic
# 7661        Andrew L. Closson            21        Male         White
# 7662            Andrew Layton            26        Male         White
#
#                                  URL of image of victim  \
# 0     https://fatalencounters.org/wp-content/uploads...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7658  http://www.tricitytribuneusa.com/wp-content/up...
# 7659  http://content.omaha.com/media/maps/ps/2013/ja...
# 7660  http://www.krdo.com/image/view/-/17980228/medR...
# 7661  http://www.superiortelegram.com/sites/default/...
# 7662  http://bloximages.chicago2.vip.townnews.com/ma...
#
#      Date of Incident (month/day/year)             Street Address of Incident  \
# 0                           12/31/2019                             Broad St.
# 1                           12/31/2019                         7239-7411 I-40
# 2                           12/31/2019                         3600 N 24th St
# 3                           12/31/2019                30800 14th Avenue South
# 4                           12/31/2019                    17057 N Outer 40 Rd
# ...                                ...                                    ...
# 7658                          1/1/2013                    912 Loma Linda Ave.
# 7659                          1/1/2013                       3727 N. 42nd St.
# 7660                          1/1/2013  Highway 50 and North Elizabeth Street
# 7661                          1/1/2013                        U.S. Highway 53
# 7662                          1/1/2013                 410 S Riverfront Drive
#
#               City State  Zipcode  ...          Unarmed  \
# 0            Globe    AZ  85501.0  ...  Allegedly Armed
# 1          Memphis    AR  38103.0  ...          Unclear
# 2            Omaha    NE  68110.0  ...  Allegedly Armed
# 3      Federal Way    WA  98003.0  ...  Allegedly Armed
# 4     Chesterfield    MO  63005.0  ...          Vehicle
# ...            ...   ...      ...  ...              ...
# 7658    Farmington    NM  87401.0  ...  Allegedly Armed
# 7659         Omaha    NE  68111.0  ...  Allegedly Armed
# 7660        Pueblo    CO  81008.0  ...  Allegedly Armed
# 7661        Gordon    WI  54838.0  ...  Allegedly Armed
# 7662       Mankato    MN  56001.0  ...          Unarmed
#
#      Alleged Weapon (Source: WaPo) Male Threat level Fleeing (Source: WaPo)  \
# 0                            knife             other            not fleeing
# 1                          unclear             other                    NaN
# 2                              gun            attack            not fleeing
# 3                              gun            attack            not fleeing
# 4                          vehicle            attack                    car
# ...                            ...               ...                    ...
# 7658                  blunt weapon               NaN                    NaN
# 7659                           gun               NaN                    NaN
# 7660                           gun               NaN                    NaN
# 7661                           gun               NaN                    NaN
# 7662                       unarmed               NaN                    NaN
#
#      Body Camera (Source: WaPo) WaPo ID (If included in WaPo database)  \
# 0                            no                                 5332.0
# 1                           NaN                                    NaN
# 2                            no                                 5359.0
# 3                            no                                 5358.0
# 4                            no                                 5333.0
# ...                         ...                                    ...
# 7658                        NaN                                    NaN
# 7659                        NaN                                    NaN
# 7660                        NaN                                    NaN
# 7661                        NaN                                    NaN
# 7662                        NaN                                    NaN
#
#      Off-Duty Killing? Geography    ID Age Demographics
# 0                  NaN     Rural  7664            26-39
# 1                  NaN     Urban  7665              NaN
# 2                  NaN     Urban  7661            40-65
# 3                  NaN  Suburban  7662            18-25
# 4                  NaN  Suburban  7667            26-39
# ...                ...       ...   ...              ...
# 7658               NaN     Urban     1            40-65
# 7659               NaN     Urban     2            26-39
# 7660               NaN  Suburban     4            18-25
# 7661               NaN     Rural     5            18-25
# 7662               NaN  Suburban     6            26-39
#
# [7253 rows x 28 columns]

# %%
# Create the bins for ages which is reference from police killings data
bins = [0, 1, 17, 24, 39, 64, 999]

# Create the names for the bins
group_names = ["unknown", "<18", "18-25", "26-39", "40-65", "65+"]

# Place the data series into a new column inside of the DataFrame
male_attack_df = male_attack
male_attack_df["Age Demographics"] = pd.cut(male_attack_df["Victim's age"], bins, labels=group_names)

# Create a GroupBy object based upon "View Group"
male_attack_group = male_attack_df.groupby("Age Demographics")

# Count male attack in each age group
male_attack_counts = male_attack_group.count()

# Select only male victim column
male_attack_counts = male_attack_counts["Male victim"]

# Count male attack percentage in total victims
male_attack_percentage = round((male_attack_counts/total_victims)*100,2)

# Count male attack percentage in total male victims
male_attack_total = male_attack_df["Male Threat level"].count()
just_male_attack_percentage = round((male_attack_counts/male_attack_total)*100,2)

# Create new data frame
male_attack_summary = pd.DataFrame({"Male attack count":male_attack_counts,"Percentage of male attack in total victims":male_attack_percentage,"Percentage of male attack in male victims":just_male_attack_percentage})

male_attack_summary
# Out:
#                   Male attack count  \
# Age Demographics
# unknown                           3
# <18                             141
# 18-25                          1143
# 26-39                          3201
# 40-65                          2348
# 65+                             231
#
#                   Percentage of male attack in total victims  \
# Age Demographics
# unknown                                                 0.04
# <18                                                     1.90
# 18-25                                                  15.42
# 26-39                                                  43.19
# 40-65                                                  31.68
# 65+                                                     3.12
#
#                   Percentage of male attack in male victims
# Age Demographics
# unknown                                                0.06
# <18                                                    2.81
# 18-25                                                 22.78
# 26-39                                                 63.80
# 40-65                                                 46.80
# 65+                                                    4.60

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
male_atk = [3, 141, 1143, 3201, 2348, 231]

# Set position of bar on X axis
r1 = np.arange(len(male_atk))

# Make the plot
plt.bar(r1, male_atk, color='purple', width=barWidth, edgecolor='white', label='Threat level: attack')

# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.ylabel('City Type Counts', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(rural))], ['Unknown', '<18', '18-25', '26-39', '40-65', '65+'])
plt.title('male victims with attack threat in Age Demographics')

# Create legend & Show graphic
plt.legend()

# Save figure
plt.savefig('male victims attack')

plt.show()

# %%
## city type vs age demographics
# Create a GroupBy object based upon "View Group"
age_group = age_df.groupby("Age Demographics")

#Calculate victims with city type in each age group
age_citytype = age_group["Geography"].value_counts()
age_citytype

# Save dataframe 
age_citytype.to_csv("citytypes_table")

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
rural = [1, 16, 172, 694, 688, 84]
suburban = [1, 80, 612, 1697, 1201, 118]
urban = [1, 53, 408, 955, 583, 37]
 
# Set position of bar on X axis
r1 = np.arange(len(rural))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Make the plot
plt.bar(r1, rural, color='yellow', width=barWidth, edgecolor='white', label='Rural')
plt.bar(r2, suburban, color='green', width=barWidth, edgecolor='white', label='Suburban')
plt.bar(r3, urban, color='brown', width=barWidth, edgecolor='white', label='Urban')
 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.ylabel('City Type Counts', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(rural))], ['Unknown', '<18', '18-25', '26-39', '40-65', '65+'])
plt.title('City types in Age Demographics')

# Create legend & Show graphic
plt.legend()

# Save figure
plt.savefig('citytypes_age')

plt.show()

# %%
# Calculate male with attck threat level in each age group

## Male: Start with filtering male from original age_df

# Replace blank with unknown in "Victim's gender" column
#age_df["Victim's gender"] = age_df["Victim's gender"].replace(' ', 'Unknown')


# Filter male in victim gender
sub_male = age_male.loc[age_male["Geography"] == "Suburban", :]

# Rename Victim's gender to male victim
#male_attack = age_male.rename(columns={"": 'Male Threat level'})

sub_male
# Out:
#                Victim's name  Victim's age Male victim Victim's race  \
# 3             Malik Williams            23        Male         Black
# 4          Frederick Perkins            37        Male         Black
# 5      Michael Vincent Davis            49        Male         White
# 12             Patrick Alden            29        Male  Unknown race
# 14    Kelly Michael Stephens            34        Male  Unknown race
# ...                      ...           ...         ...           ...
# 7652         Barry Cloninger            51        Male         White
# 7654   Chandler T. Guinn Jr.            23        Male  Unknown race
# 7655       Hunter Jacob Todd            20        Male         White
# 7660     Christopher Tavares            21        Male      Hispanic
# 7662           Andrew Layton            26        Male         White
#
#                                  URL of image of victim  \
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 12                                                  NaN
# 14                                                  NaN
# ...                                                 ...
# 7652  http://altondailynews.interactivemediapartners...
# 7654                                                NaN
# 7655  http://ak-cache.legacy.net/legacy/Images/Cobra...
# 7660  http://www.krdo.com/image/view/-/17980228/medR...
# 7662  http://bloximages.chicago2.vip.townnews.com/ma...
#
#      Date of Incident (month/day/year)             Street Address of Incident  \
# 3                           12/31/2019                30800 14th Avenue South
# 4                           12/31/2019                    17057 N Outer 40 Rd
# 5                           12/31/2019                            Dawn Street
# 12                          12/29/2019                     851 E Minnesota St
# 14                          12/29/2019                         9160 Cinema Dr
# ...                                ...                                    ...
# 7652                          1/4/2013                            7100 IL-140
# 7654                          1/3/2013          52nd Street and Troost Avenue
# 7655                          1/3/2013                  8000 Debbie Ann Court
# 7660                          1/1/2013  Highway 50 and North Elizabeth Street
# 7662                          1/1/2013                 410 S Riverfront Drive
#
#                 City State  Zipcode  ...          Unarmed  \
# 3        Federal Way    WA  98003.0  ...  Allegedly Armed
# 4       Chesterfield    MO  63005.0  ...          Vehicle
# 5        Cross Lanes    WV  25313.0  ...  Allegedly Armed
# 12        Rapid City    SD  57701.0  ...  Allegedly Armed
# 14            Juneau    AK  99801.0  ...          Unclear
# ...              ...   ...      ...  ...              ...
# 7652    Edwardsville    IL  62025.0  ...  Allegedly Armed
# 7654     Kansas City    MO  64110.0  ...  Allegedly Armed
# 7655  Citrus Heights    CA  95610.0  ...          Unarmed
# 7660          Pueblo    CO  81008.0  ...  Allegedly Armed
# 7662         Mankato    MN  56001.0  ...          Unarmed
#
#      Alleged Weapon (Source: WaPo) Victim Threat level Fleeing (Source: WaPo)  \
# 3                              gun              attack            not fleeing
# 4                          vehicle              attack                    car
# 5                              gun              attack                   Foot
# 12                             gun              attack            Not fleeing
# 14                           chain               other            Not fleeing
# ...                            ...                 ...                    ...
# 7652                           gun                 NaN                    NaN
# 7654                           gun                 NaN                    NaN
# 7655                       unarmed                 NaN                    NaN
# 7660                           gun                 NaN                    NaN
# 7662                       unarmed                 NaN                    NaN
#
#      Body Camera (Source: WaPo) WaPo ID (If included in WaPo database)  \
# 3                            no                                 5358.0
# 4                            no                                 5333.0
# 5                            No                                 5374.0
# 12                           No                                 5311.0
# 14                           No                                 5313.0
# ...                         ...                                    ...
# 7652                        NaN                                    NaN
# 7654                        NaN                                    NaN
# 7655                        NaN                                    NaN
# 7660                        NaN                                    NaN
# 7662                        NaN                                    NaN
#
#      Off-Duty Killing? Geography    ID Age Demographics
# 3                  NaN  Suburban  7662            18-25
# 4                  NaN  Suburban  7667            26-39
# 5                  NaN  Suburban  7663            40-65
# 12                 NaN  Suburban  7655            26-39
# 14                 NaN  Suburban  7653            26-39
# ...                ...       ...   ...              ...
# 7652               NaN  Suburban    11            40-65
# 7654               NaN  Suburban     9            18-25
# 7655               NaN  Suburban    10            18-25
# 7660               NaN  Suburban     4            18-25
# 7662               NaN  Suburban     6            26-39
#
# [3578 rows x 28 columns]

# %%
# Create the bins for ages which is reference from police killings data
bins = [0, 1, 17, 24, 39, 64, 999]

# Create the names for the bins
group_names = ["unknown", "<18", "18-25", "26-39", "40-65", "65+"]

# Place the data series into a new column inside of the DataFrame
sub_male_df = sub_male
sub_male_df["Age Demographics"] = pd.cut(sub_male_df["Victim's age"], bins, labels=group_names)

# Create a GroupBy object based upon "View Group"
sub_male_group = sub_male_df.groupby("Age Demographics")

# Count male attack in each age group
sub_male_counts = sub_male_group.count()

# Select only male victim column
sub_male_counts = sub_male_counts["Male victim"]

# Count male attack percentage in total victims
sub_male_percentage = round((sub_male_counts/total_victims)*100,2)

# Count male attack percentage in total male victims
sub_male_total = male_attack_df["Geography"].count()
just_sub_male_percentage = round((sub_male_counts/sub_male_total)*100,2)

# Create new data frame
sub_male_summary = pd.DataFrame({"Sub Male victims count":sub_male_counts,"Percentage of male victim in sub in total victims":sub_male_percentage,"Percentage of male victim in sub in male victims":just_sub_male_percentage})

sub_male_summary
# Out:
#                   Sub Male victims count  \
# Age Demographics
# unknown                                1
# <18                                   71
# 18-25                                575
# 26-39                               1607
# 40-65                               1124
# 65+                                  111
#
#                   Percentage of male victim in sub in total victims  \
# Age Demographics
# unknown                                                        0.01
# <18                                                            0.96
# 18-25                                                          7.76
# 26-39                                                         21.68
# 40-65                                                         15.17
# 65+                                                            1.50
#
#                   Percentage of male victim in sub in male victims
# Age Demographics
# unknown                                                       0.01
# <18                                                           0.99
# 18-25                                                         8.00
# 26-39                                                        22.35
# 40-65                                                        15.63
# 65+                                                           1.54

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
male_sub = [1, 71, 575, 1607, 1124, 111]

# Set position of bar on X axis
r1 = np.arange(len(male_sub))

# Make the plot
plt.bar(r1, rural, color='red', width=barWidth, edgecolor='white', label='Geography: Suburban')

# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.ylabel('City Type Counts', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(rural))], ['Unknown', '<18', '18-25', '26-39', '40-65', '65+'])
plt.title('male victims in suburban in Age Demographics')

# Create legend & Show graphic
plt.legend()

# Save figure
plt.savefig('sub_male')

plt.show()
